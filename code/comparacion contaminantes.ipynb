# %%
import pandas as pd
import numpy as np
import time
import calendar
import datetime 
import scipy.stats
from matplotlib import pyplot as plt
import seaborn as sns
pd.options.display.max_rows = 53000
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
from math import sqrt
# %matplotlib inline

# %%
data = pd.read_csv('/mnt/c/users/marcj/Desktop/MASTER/TFM/DADES POLLUTION/master-data-science/data/Eixample/notebook-serie-Eix_NO2-19', parse_dates= ['DATA'], index_col='DATA',header=0)

# %%
data_1 = pd.read_csv('/mnt/c/users/marcj/Desktop/MASTER/TFM/DADES POLLUTION/Notebooks/datasets/19/notebook_serie-SO2-19', parse_dates= ['DATA'], index_col='DATA',header=0)

# %%
data_2 = pd.read_csv('/mnt/c/users/marcj/Desktop/MASTER/TFM/DADES POLLUTION/Notebooks/datasets/19/notebook_serie-CO-19', parse_dates= ['DATA'], index_col='DATA',header=0)

# %%
data.plot()

# %%
data_1.plot()

# %%
data_2.plot()
